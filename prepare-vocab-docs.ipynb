# %%
# !pip install -U tables scikit-learn gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already up-to-date: tables in /home/users/sljack/.local/lib/python3.7/site-packages (3.6.1)
# Requirement already up-to-date: scikit-learn in /home/users/sljack/.local/lib/python3.7/site-packages (0.23.1)
# Requirement already up-to-date: gensim in /home/users/sljack/.local/lib/python3.7/site-packages (3.8.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.3 in /opt/jaspy/lib/python3.7/site-packages (from tables) (1.15.4)
# Requirement already satisfied, skipping upgrade: numexpr>=2.6.2 in /home/users/sljack/.local/lib/python3.7/site-packages (from tables) (2.7.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /opt/jaspy/lib/python3.7/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /opt/jaspy/lib/python3.7/site-packages (from scikit-learn) (0.13.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /home/users/sljack/.local/lib/python3.7/site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in /opt/jaspy/lib/python3.7/site-packages (from gensim) (1.12.0)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in /home/users/sljack/.local/lib/python3.7/site-packages (from gensim) (2.0.0)
# Requirement already satisfied, skipping upgrade: boto3 in /opt/jaspy/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim) (1.9.67)
# Requirement already satisfied, skipping upgrade: boto in /home/users/sljack/.local/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied, skipping upgrade: requests in /opt/jaspy/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim) (2.21.0)
# Requirement already satisfied, skipping upgrade: botocore<1.13.0,>=1.12.67 in /opt/jaspy/lib/python3.7/site-packages (from boto3->smart-open>=1.8.1->gensim) (1.12.68)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /opt/jaspy/lib/python3.7/site-packages (from boto3->smart-open>=1.8.1->gensim) (0.9.3)
# Requirement already satisfied, skipping upgrade: s3transfer<0.2.0,>=0.1.10 in /opt/jaspy/lib/python3.7/site-packages (from boto3->smart-open>=1.8.1->gensim) (0.1.13)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /opt/jaspy/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /opt/jaspy/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (1.24.1)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /opt/jaspy/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/jaspy/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: docutils>=0.10 in /opt/jaspy/lib/python3.7/site-packages (from botocore<1.13.0,>=1.12.67->boto3->smart-open>=1.8.1->gensim) (0.14)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in /opt/jaspy/lib/python3.7/site-packages (from botocore<1.13.0,>=1.12.67->boto3->smart-open>=1.8.1->gensim) (2.7.5)

# %%
import requests
import bs4
import pandas as pd
import numpy as np
import gensim

from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # Prepare Vocabulary Documents
#
# We're going to pull some climate vocabularies from the web which can be used to give context to the meta data from the CEDA archive
#
# ## Climate & Forecast Metadata Conventions
#
# The first set of vocabulary we're going to look at is the [CF conventions](https://en.wikipedia.org/wiki/Climate_and_Forecast_Metadata_Conventions#:~:text=The%20Climate%20and%20Forecast%20(CF,file%20%22self%2Ddescribing%22.) and are used to define variables found in NetCDF files. The CF conventions have the benefit that they come with a nice human readbable description alongside the variables.
#
# The first thing we need to do is ge the CF conventions from the web:

# %%
response = requests.get('https://cfconventions.org/Data/cf-standard-names/73/src/cf-standard-name-table.xml')
cf_xml = response.text

# %% [markdown]
# We can use the BeautifulSoup library to parse the XML file and give us an object we can query. Here we output just the first entry in the CF conventions

# %%
cf_soup = bs4.BeautifulSoup(cf_xml, 'lxml')
tag = cf_soup.find('entry')
tag
# Out:
# <entry id="acoustic_signal_roundtrip_travel_time_in_sea_water">
# <canonical_units>s</canonical_units>
# <grib></grib>
# <amip></amip>
# <description>The quantity with standard name acoustic_signal_roundtrip_travel_time_in_sea_water is the time taken for an acoustic signal to propagate from the emitting instrument to a reflecting surface and back again to the instrument. In the case of an instrument based on the sea floor and measuring the roundtrip time to the sea surface, the data are commonly used as a measure of ocean heat content.</description>
# </entry>

# %% [markdown]
# Convert the CF entries into a pandas DataFrame where they are indexed by the CF variable name ID

# %%
cf_entries = cf_soup.findAll('entry')
cf_data = [dict(id=entry.get('id'), description=entry.find('description').text, unit=entry.find('canonical_units').text) for entry in cf_entries]
cf_df = pd.DataFrame(cf_data)
# cf_df = cf_df.loc[cf_df.description.map(len) > 0]
cf_df.to_hdf('data/vocabs/cf_conventions.h5', key='data')
cf_df.head(20)
# Out:
#                                           description  \
# 0   The quantity with standard name acoustic_signa...
# 1   The diameter of a spherical particle with dens...
# 2   The "aerodynamic_resistance" is the resistance...
# 3   "Age of sea ice" means the length of time elap...
# 4   "Age of stratospheric air" means an estimate o...
# 5   "Age of surface snow" means the length of time...
# 6   This flag is an algorithmic combination of the...
# 7
# 8   The "equivalent potential temperature" is a th...
# 9   The equivalent temperature is the temperature ...
# 10  Air potential temperature is the temperature a...
# 11  Air pressure is the force per unit area which ...
# 12  The term "anomaly" means difference from clima...
# 13  The phrase "cloud_base" refers to the base of ...
# 14  The phrase "cloud_top" refers to the top of th...
# 15  The phrase "cloud_base" refers to the base of ...
# 16  The phrase "cloud_top" refers to the top of th...
# 17  Air pressure is the force per unit area which ...
# 18  Air pressure at sea level is the quantity ofte...
# 19  "Top of atmosphere model" means the upper boun...
#
#                                                    id    unit
# 0   acoustic_signal_roundtrip_travel_time_in_sea_w...       s
# 1                       aerodynamic_particle_diameter       m
# 2                              aerodynamic_resistance   m-1 s
# 3                                      age_of_sea_ice    year
# 4                            age_of_stratospheric_air       s
# 5                                 age_of_surface_snow     day
# 6                              aggregate_quality_flag       1
# 7                                         air_density  kg m-3
# 8                air_equivalent_potential_temperature       K
# 9                          air_equivalent_temperature       K
# 10                          air_potential_temperature       K
# 11                                       air_pressure      Pa
# 12                               air_pressure_anomaly      Pa
# 13                         air_pressure_at_cloud_base      Pa
# 14                          air_pressure_at_cloud_top      Pa
# 15              air_pressure_at_convective_cloud_base      Pa
# 16               air_pressure_at_convective_cloud_top      Pa
# 17                     air_pressure_at_freezing_level      Pa
# 18                     air_pressure_at_mean_sea_level      Pa
# 19            air_pressure_at_top_of_atmosphere_model      Pa

# %% [markdown]
# Convert the vocaulary from the CF conventions to a document matrix, where the document name is the id of the CF convention and the document vector is defined by terms from the description of the CF entry.

# %%
vectorizer = CountVectorizer(token_pattern=r'[a-zA-Z0-9]{3,}', ngram_range=(1, 1), 
                             min_df=0., max_df=.98, stop_words='english', lowercase=True)
tokenizer = vectorizer.build_analyzer()
tokens = cf_df.description.map(tokenizer)

id2word = gensim.corpora.Dictionary(tokens)
bow = [id2word.doc2bow(text) for text in tokens]

cf_embedding = gensim.matutils.corpus2csc(bow).T
cf_embedding = np.array(cf_embedding.todense())

columns = [id2word[x] for x in id2word]
cf_embedding = pd.DataFrame(cf_embedding, index=cf_df.id, columns=columns)
cf_embedding.to_hdf('data/embeddings/cf_embedding.h5', key='data')
cf_embedding.head()
# Out:
#                                                     acoustic  based  case  \
# id
# acoustic_signal_roundtrip_travel_time_in_sea_water       2.0    1.0   1.0
# aerodynamic_particle_diameter                            0.0    0.0   0.0
# aerodynamic_resistance                                   0.0    0.0   0.0
# age_of_sea_ice                                           0.0    0.0   0.0
# age_of_stratospheric_air                                 0.0    0.0   0.0
#
#                                                     commonly  content  data  \
# id
# acoustic_signal_roundtrip_travel_time_in_sea_water       1.0      1.0   1.0
# aerodynamic_particle_diameter                            0.0      0.0   0.0
# aerodynamic_resistance                                   0.0      0.0   0.0
# age_of_sea_ice                                           0.0      0.0   0.0
# age_of_stratospheric_air                                 0.0      0.0   0.0
#
#                                                     emitting  floor  heat  \
# id
# acoustic_signal_roundtrip_travel_time_in_sea_water       1.0    1.0   1.0
# aerodynamic_particle_diameter                            0.0    0.0   0.0
# aerodynamic_resistance                                   0.0    0.0   0.0
# age_of_sea_ice                                           0.0    0.0   0.0
# age_of_stratospheric_air                                 0.0    0.0   0.0
#
#                                                     instrument     ...      \
# id                                                                 ...
# acoustic_signal_roundtrip_travel_time_in_sea_water         3.0     ...
# aerodynamic_particle_diameter                              0.0     ...
# aerodynamic_resistance                                     0.0     ...
# age_of_sea_ice                                             0.0     ...
# age_of_stratospheric_air                                   0.0     ...
#
#                                                     flowing  bulb  brief  \
# id
# acoustic_signal_roundtrip_travel_time_in_sea_water      0.0   0.0    0.0
# aerodynamic_particle_diameter                           0.0   0.0    0.0
# aerodynamic_resistance                                  0.0   0.0    0.0
# age_of_sea_ice                                          0.0   0.0    0.0
# age_of_stratospheric_air                                0.0   0.0    0.0
#
#                                                     gust  gustiness  \
# id
# acoustic_signal_roundtrip_travel_time_in_sea_water   0.0        0.0
# aerodynamic_particle_diameter                        0.0        0.0
# aerodynamic_resistance                               0.0        0.0
# age_of_sea_ice                                       0.0        0.0
# age_of_stratospheric_air                             0.0        0.0
#
#                                                     parametrised  sudden  \
# id
# acoustic_signal_roundtrip_travel_time_in_sea_water           0.0     0.0
# aerodynamic_particle_diameter                                0.0     0.0
# aerodynamic_resistance                                       0.0     0.0
# age_of_sea_ice                                               0.0     0.0
# age_of_stratospheric_air                                     0.0     0.0
#
#                                                     timeseries  keeping  \
# id
# acoustic_signal_roundtrip_travel_time_in_sea_water         0.0      0.0
# aerodynamic_particle_diameter                              0.0      0.0
# aerodynamic_resistance                                     0.0      0.0
# age_of_sea_ice                                             0.0      0.0
# age_of_stratospheric_air                                   0.0      0.0
#
#                                                     presumably
# id
# acoustic_signal_roundtrip_travel_time_in_sea_water         0.0
# aerodynamic_particle_diameter                              0.0
# aerodynamic_resistance                                     0.0
# age_of_sea_ice                                             0.0
# age_of_stratospheric_air                                   0.0
#
# [5 rows x 3866 columns]
